# %% [markdown]
# # XGBClassifier - 分類電商商品名

# %%
# !pip install jieba
import pandas as pd
import numpy as np
import re
from sklearn.utils import shuffle
import torch
import jieba
import jieba.analyse as analyse
import jieba.posseg as pseg  # 詞性標註
from torchtext.data.utils import get_tokenizer
from torchtext.vocab import build_vocab_from_iterator
from sklearn.feature_extraction.text import TfidfVectorizer

jieba.load_userdict("./dict.txt")  # 匯入自訂義斷詞字典
# Out:
# Building prefix dict from the default dictionary ...
# Loading model from cache C:\Users\user\AppData\Local\Temp\jieba.cache
# Loading model cost 0.628 seconds.
# Prefix dict has been built successfully.

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
df = pd.read_csv("./dataset/result_online.csv", encoding="utf-8")
print(df.head())
# Out:
#    item_id         item_name item_category_item_category2
# 0   505462         大維錠狀食品純素錠                   保健/醫療|機能保健
# 1   510277  樟芝天然綜合水果益生菌酵素發酵液                   保健/醫療|機能保健
# 2   473902         養氣人蔘禮盒ml入                   保健/醫療|機能保健
# 3   406767           雪麗維他命C錠                   保健/醫療|機能保健
# 4   322386         勇健鈣鎂鋅加強錠錠                   保健/醫療|機能保健

# %%
product_name_list = list(df['item_name'])
label = list(df['item_category_item_category2'])

print(len(np.unique(label)))  # 印資料的label有多少獨立類別

# concat product_name_list與label為一dataframe
df = pd.DataFrame(
    {'product_name': product_name_list,
     'item_category12': label
    })
print(df.item_category12.value_counts())  # 印出每類數量
# Out:
# 407
# 圖書影音|文學小說        3846
# 圖書影音|童書/教具       3422
# 服飾|女裝            2766
# 傢俱收納|櫥櫃/櫃子       2730
# 鞋包箱|運動鞋          2362
#                  ...
# 彩妝保養|彩妝刷具           1
# 精品/飾品|鐘錶周邊          1
# 手機/平板|SONY相機        1
# 看看買|BEBEPOSHE       1
# 生鮮|冷凍快配             1
# Name: item_category12, Length: 407, dtype: int64

# %% [markdown]
# ## 類別平衡

# %%
# 做類別平衡&打亂
# 由於硬體設備限制，對於category1+2每類只平衡至200

shuffled = df
data = []
unique_label = np.unique(np.unique(df.item_category12)).tolist()  # 不重複category1+2

# 對各Category抽樣n筆資料
for i in unique_label:
    globals()['name' + str(i)] = shuffled[shuffled['item_category12'] == i].sample(n=200,replace=True)
    data.append(globals()['name' + str(i)])

# concat the dataset 將各Category合併
concated = data[0]
for i in range(1,len(unique_label)):
    concated = pd.concat([concated, data[i]], ignore_index=True)

# Shuffle the dataset
concated = shuffle(concated)

# 重新assign index
concated.reset_index(drop=True, inplace=True)
print(concated.shape)  # (81400, 2): 每個category1+2有200筆資料，包含product_name&item_category12兩欄
print(concated.head())
# Out:
# (81400, 2)
#           product_name item_category12
# 0          透明衣物收納防塵套小#    傢俱收納|壓縮袋/收納袋
# 1     矜蘭妃蠶絲石墨烯下半身幸福男內褲     看看買|看看買-內塑衣
# 2         英吋打蠟機拋光布件超值組       修繕園藝|電動工具
# 3  職場通勤健步美型簡約漆皮扣後拉帶中跟鞋       鞋包箱|品牌休閒鞋
# 4               電擊式捕蚊燈         家電|捕蚊家電

# %%
# 檢查有無空值
concated.isna().sum()
# Out:
# product_name       0
# item_category12    0
# dtype: int64

# %%
# 把中文字以外的字元拿掉
rule = re.compile(r"[^\u4e00-\u9fa5]")
concated['product_name'] = [rule.sub('', name) for name in concated['product_name']]
print(concated['product_name'][:5])
# Out:
# 0             透明衣物收納防塵套小
# 1       矜蘭妃蠶絲石墨烯下半身幸福男內褲
# 2           英吋打蠟機拋光布件超值組
# 3    職場通勤健步美型簡約漆皮扣後拉帶中跟鞋
# 4                 電擊式捕蚊燈
# Name: product_name, dtype: object

# %%
# 載入停用字檔案
with open('stop_words.txt', encoding="utf-8") as f:
    stopword_list = [s for s in f.read().split('\n')]

# %%
# 斷詞(3種version: cut/topk: 選k個最重要的特徵/posseg: 依詞性斷詞)
seg_product_name = []
count = 0
for name in concated['product_name']:
    name = ''.join([w for w in name if w not in stopword_list])
    seg_product_name.append([w for w in jieba.cut(name)])
#     seg_product_name.append([w for w in jieba.analyse.extract_tags(name, topK=3, withWeight=False, allowPOS=())])
"""
    seg = []
    generator = pseg.cut(name)  # 返回生成器
    for word, flag in generator:   # word為斷的字/詞; flag為對應詞性
        # 去除形容詞、副詞與無詞性
        if(flag == 'a' or flag == 'd' or flag == 'ad' or flag == 'x'):  
            continue
        seg.append(word)
    seg_product_name.append(seg)
"""
print(seg_product_name[:5])
# Out:
# [['透明', '衣物', '收納', '防塵套'], ['矜蘭妃', '蠶絲', '石墨', '烯身', '幸福', '男褲'], ['英', '吋', '蠟機', '拋布件', '超值', '組'], ['職場', '通勤', '健步', '美型', '簡約', '漆皮', '扣拉中', '鞋'], ['電擊式', '捕', '蚊燈']]

# %%
for idx, name in enumerate(seg_product_name):
    seg_product_name[idx] = ' '.join([word for word in name])
print(seg_product_name[:5])
# Out:
# ['透明 衣物 收納 防塵套', '矜蘭妃 蠶絲 石墨 烯身 幸福 男褲', '英 吋 蠟機 拋布件 超值 組', '職場 通勤 健步 美型 簡約 漆皮 扣拉中 鞋', '電擊式 捕 蚊燈']

# %% [markdown]
# ## 特徵提取&降維

# %%
tfidf = TfidfVectorizer(max_df = 0.7, ngram_range=(1, 2), sublinear_tf=True, norm='l2', min_df = 0.00004)
features = tfidf.fit_transform(seg_product_name).toarray()
print(features.shape)
# Out:
# (81400, 20253)

# %%
X = features
y = concated['item_category12']

# %%
# Dimenionality reduction. Only using the 100 best features per category
from sklearn.decomposition import PCA
pca = PCA(n_components= 100,random_state=3)
X = pca.fit_transform(X)
X.shape

# Deal with PCA memory error 
# https://scikit-learn.org/stable/modules/generated/sklearn.decomposition.TruncatedSVD.html 
from sklearn import decomposition 
"""
svd = decomposition.TruncatedSVD(n_components = 100, algorithm='arpack')
X = svd.fit_transform(features)
print(X.shape)
print(svd.explained_variance_ratio_.sum())
"""
# Out:
# "\nsvd = decomposition.TruncatedSVD(n_components = 100, algorithm='arpack')\nX = svd.fit_transform(features)\nprint(X.shape)\nprint(svd.explained_variance_ratio_.sum())\n"

# %%
# Train test split 
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X,
                                                    y,
                                                    test_size=.2,
                                                    random_state=3)

# %%
from xgboost import XGBClassifier
# model = XGBClassifier(tree_method='gpu_hist')
model = XGBClassifier(
        n_estimators=100, #樹的個數
        learning_rate= 0.5,   
        max_depth = 6,  # 構建樹的深度，越大越容易過擬合   
        subsample= 0.1, # 隨機取樣訓練樣本 訓練例項的子取樣比
        gamma= 0.1, # 用於控制是否後剪枝的引數,越大越保守，一般0.1、0.2這樣子
        reg_lambda=1,   # 控制模型複雜度的權重值的L2正則化項引數，引數越大，模型越不容易過擬合。
        colsample_bytree= 1, #最大增量步長，我們允許每個樹的權重估計。
    
        # 這個引數預設是 1，是每個葉子裡面 h 的和至少是多少，對正負樣本不均衡時的 0-1 分類而言
        # 假設 h 在 0.01 附近，min_child_weight 為 1 意味著葉子節點中最少需要包含 100 個樣本。
        #這個引數非常影響結果，控制葉子節點中二階導的和的最小值，該引數值越小，越容易 overfitting。
        min_child_weight = 1, 
        reg_alpha=0, # L1 正則項引數
        scale_pos_weight=1, #如果取值大於0的話，在類別樣本不平衡的情況下有助於快速收斂。平衡正負權重
        objective= 'multi:softmax', 
        silent=0 , # 設定成1則沒有執行資訊輸出，最好是設定為0.是否在執行升級時列印訊息。
        nthread=8,
        eval_metric= 'auc',
        tree_method = 'gpu_hist')
model.fit(X_train, y_train)
# Out:
# C:\Users\user\Anaconda3\envs\pytorch_p36\lib\site-packages\xgboost\sklearn.py:1224: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# C:\Users\user\Anaconda3\envs\pytorch_p36\lib\site-packages\sklearn\utils\validation.py:63: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   return f(*args, **kwargs)
# [23:12:10] WARNING: C:/Users/Administrator/workspace/xgboost-win64_release_1.5.1/src/learner.cc:576:
# Parameters: { "scale_pos_weight", "silent" } might not be used.
#
#   This could be a false alarm, with some parameters getting used by language bindings but
#   then being mistakenly passed down to XGBoost core, or some parameter actually being used
#   but getting flagged wrongly here. Please open an issue if you find any such cases.
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=1, enable_categorical=False,
#               eval_metric='auc', gamma=0.1, gpu_id=0, importance_type=None,
#               interaction_constraints='', learning_rate=0.5, max_delta_step=0,
#               max_depth=6, min_child_weight=1, missing=nan,
#               monotone_constraints='()', n_estimators=100, n_jobs=8, nthread=8,
#               num_parallel_tree=1, objective='multi:softprob', predictor='auto',
#               random_state=0, reg_alpha=0, reg_lambda=1, scale_pos_weight=1,
#               silent=0, subsample=0.1, tree_method='gpu_hist', ...)

# %%
# Save Model
import pickle

with open("XGB_model_cat1_cut.pkl", "wb") as file:
    pickle.dump(model, file)

# %% [markdown]
# ## 預測Testing set (以下為預測offline data)

# %%
# 匯入模型
with open("XGB_model_cat12_cut.pkl", "rb") as file:
   model = pickle.load(file)

# %%
# 匯入offline data
testing_set = pd.read_csv("./dataset/統一資料集/offline_result.csv", encoding="utf-8")
testing_set = testing_set[:191]
print(testing_set.tail())
# Out:
#      sid      id  Original Item Name Preprocessed Item Name category1  \
# 186  186   82595               美國青花菜                  美國青花菜        生鮮
# 187  187   38029  TOMMY’S BAKING軟質餅乾      TOMMY’SBAKING軟質餅乾      食品飲料
# 188  188   90667            A++金牌肉燥飯                 A金牌肉燥飯      食品飲料
# 189  189  100950            奇蹟活源水精華1                奇蹟活源水精華      彩妝保養
# 190  190   59360          怡麗絲爾彈潤時控精粹             怡麗絲爾彈潤時控精粹      彩妝保養
#
#     category2    cat1|cat2  Unnamed: 7 Unnamed: 8 Unnamed: 9  Unnamed: 10  \
# 186      蔬菜水果      生鮮|蔬菜水果         NaN        NaN        NaN          NaN
# 187      休閒零食    食品飲料|休閒零食         NaN        NaN        NaN          NaN
# 188    米/麵/泡麵  食品飲料|米/麵/泡麵         NaN        NaN        NaN          NaN
# 189    專櫃保養品牌  彩妝保養|專櫃保養品牌         NaN        NaN        NaN          NaN
# 190    專櫃保養品牌  彩妝保養|專櫃保養品牌         NaN        NaN        NaN          NaN
#
#      Unnamed: 11  Unnamed: 12 Unnamed: 13 Unnamed: 14
# 186          NaN          NaN         NaN         NaN
# 187          NaN          NaN         NaN         NaN
# 188          NaN          NaN         NaN         NaN
# 189          NaN          NaN         NaN         NaN
# 190          NaN          NaN         NaN         NaN

# %%
# 斷詞&去除stopwords
processed_testing = []

for i in range(0, len(testing_set['Preprocessed Item Name'])):
    # 把中文字以外的字元拿掉
    seg = rule.sub('', testing_set['Preprocessed Item Name'][i])
    seg = ''.join([w for w in seg if w not in stopword_list])
    seg = ' '.join([w for w in jieba.cut(seg)])
    processed_testing.append(seg)

print(processed_testing[:10])  # X
print(testing_set['cat1|cat2'][:10])  # y
print(len(processed_testing))
print(len(testing_set['cat1|cat2']))
# Out:
# 0        食品飲料|蛋糕甜點
# 1        食品飲料|進口零食
# 2        個人清潔|身體清潔
# 3      彩妝保養|開架彩妝品牌
# 4      彩妝保養|開架保養品牌
# 5        食品飲料|進口零食
# 6      彩妝保養|開架彩妝品牌
# 7        餐廚用品|碗盤餐具
# 8    食品飲料|罐頭/食材/烘焙
# 9          彩妝保養|香水
# Name: cat1|cat2, dtype: object
# ['熊餅 乾 草莓 蛋糕 風味', '西村 嬰 野菜 蛋 酥', '熊野 油脂 超酷 涼 沐', '時尚 師色 眼影 盤 冷淡 沙漠', '保濕全 修護組', '黑巧克', '奢華 訂 製 鏡 水 唇 釉', '僑俐', '法國 洛克 福 乾酪', '香水 系列']
# 191
# 191

# %%
# tfidf特徵提取 + PCA降維(or truncated SVD)
tfidf = TfidfVectorizer(max_df = 0.7, ngram_range=(1, 2), sublinear_tf=True, norm='l2', min_df = 0.00004)
features_testing = tfidf.fit_transform(processed_testing).toarray()

from sklearn.decomposition import PCA
pca = PCA(n_components= 100,random_state=3)
X_test = pca.fit_transform(features_testing)

print(X_test.shape)
y_test = testing_set['cat1|cat2']
# Out:
# (191, 100)

# %%
#Parameters:
#   prediction: (List)預測結果; Y: (List)對應答案; classes: 包含所有分類的List
#Returns:
#   Overall precision, List of (class, precision, recall)
def precision_and_recall(prediction, Y, classes):

    count_dic = {}
    correct_dic = {}

    all_prec = float()
    class_prec = {}
    class_recall = {}
    ret = []

    #Overall precision/accuracy
    
    correct = 0
    for idx, s in enumerate(prediction):
        if s == Y[idx]:
            correct += 1
    all_prec = correct / len(Y)
    
#########################################

    #Recall of classes
    
    # 先初始化list
    for s in classes:
        count_dic[s] = 0
        correct_dic[s] = 0

    for idx, s in enumerate(Y):  # 對於每個正確答案類別
        count_dic[s] += 1    # 正確答案的各類別數ex. 正確答案是保健/醫療的有幾個(包含預測錯&預測對的)
        if s == prediction[idx]:   # 猜對的有幾個 ex. 猜對是保健/醫療的有幾個
            correct_dic[s] += 1

    for s in classes:
        if count_dic[s] == 0:
            class_recall[s] = None
        else:
            # 每個類別中，猜對數/答案是那個類別的數量
            class_recall[s] = correct_dic[s] / count_dic[s]
            
#######################################

    #Precision of classes
    
    # 先初始化list
    for s in classes:
        count_dic[s] = 0
        correct_dic[s] = 0

    for idx, s in enumerate(prediction):   # 對於每個預測的類別
        count_dic[s] += 1    # 模型猜某類別的數量ex. 預測是保健/醫療的有幾個(包含預測錯&對)
        if s == Y[idx]:    
            correct_dic[s] += 1    # 有猜對是某類別的數量ex. 正確答案也是保健/醫療的有幾個(預測對的)

    for s in classes:
        if count_dic[s] == 0:
            class_prec[s] = None
        else:
            # 每個類別中，猜對是那個類別的數量/所有猜那個類別的數量
            class_prec[s] = correct_dic[s] / count_dic[s]
            
######

    #Return
    for s in classes:
        ret.append((s, class_prec[s], class_recall[s]))

    return all_prec, ret

# %%
prediction = model.predict(X_test)
precision, recall = precision_and_recall(prediction.tolist(), y_test.tolist(), unique_label)

print("precision: ", precision)
print("precision and recall of classes: \n")
for s in recall:
    print("Class ", s[0], "\nPrecision: ", s[1], "\nRecall: ", s[2], "\n\n", sep='')
# Out:
# precision:  0.0
# precision and recall of classes:
#
# Class outlet名品匯|品牌寢具
# Precision: None
# Recall: None
#
#
# Class outlet名品匯|國際精品
# Precision: None
# Recall: 0.0
#
#
# Class 保健/醫療|DV笛絲薇夢
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|Simply新普利
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|保健用品/體重(脂)計
# Precision: 0.0
# Recall: None
#
#
# Class 保健/醫療|保險套/潤滑液
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|兒童保健
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|冷熱敷墊/護具
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|口罩/抗菌/防蚊
# Precision: None
# Recall: 0.0
#
#
# Class 保健/醫療|台糖/李時珍
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|娘家/消費高手
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|媽媽寶寶
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|成人營養品
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|機能保健
# Precision: None
# Recall: 0.0
#
#
# Class 保健/醫療|益生菌
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|看看買-嚴選保健
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|窈窕美體
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|維他命
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|葉黃素
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|輔具/日常護理/藥品
# Precision: None
# Recall: 0.0
#
#
# Class 保健/醫療|逆齡美妍/生理調養
# Precision: 0.0
# Recall: None
#
#
# Class 保健/醫療|運動保健/代餐
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|關鍵保健
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|防護專區
# Precision: None
# Recall: None
#
#
# Class 保健/醫療|順暢保養
# Precision: None
# Recall: None
#
#
# Class 修繕園藝|五金工具
# Precision: None
# Recall: None
#
#
# Class 修繕園藝|地板/裝潢
# Precision: None
# Recall: None
#
#
# Class 修繕園藝|居安防護
# Precision: 0.0
# Recall: None
#
#
# Class 修繕園藝|廚房設備
# Precision: 0.0
# Recall: None
#
#
# Class 修繕園藝|油漆
# Precision: None
# Recall: None
#
#
# Class 修繕園藝|燈泡/燈飾
# Precision: None
# Recall: None
#
#
# Class 修繕園藝|花束園藝
# Precision: 0.0
# Recall: None
#
#
# Class 修繕園藝|衛浴設備
# Precision: None
# Recall: None
#
#
# Class 修繕園藝|電動工具
# Precision: 0.0
# Recall: None
#
#
# Class 個人清潔|染髮造型
# Precision: None
# Recall: None
#
#
# Class 個人清潔|沙龍髮品
# Precision: None
# Recall: None
#
#
# Class 個人清潔|洗臉卸妝
# Precision: None
# Recall: 0.0
#
#
# Class 個人清潔|洗髮精/潤護髮
# Precision: None
# Recall: 0.0
#
#
# Class 個人清潔|牙膏牙刷
# Precision: None
# Recall: 0.0
#
#
# Class 個人清潔|男士清潔
# Precision: None
# Recall: None
#
#
# Class 個人清潔|衛生棉
# Precision: None
# Recall: None
#
#
# Class 個人清潔|身體清潔
# Precision: 0.0
# Recall: 0.0
#
#
# Class 傢俱收納|品牌傢俱
# Precision: None
# Recall: None
#
#
# Class 傢俱收納|壓縮袋/收納袋
# Precision: None
# Recall: 0.0
#
#
# Class 傢俱收納|層架
# Precision: None
# Recall: None
#
#
# Class 傢俱收納|床架
# Precision: None
# Recall: None
#
#
# Class 傢俱收納|收納架
# Precision: 0.0
# Recall: None
#
#
# Class 傢俱收納|收納櫃/箱/盒
# Precision: None
# Recall: 0.0
#
#
# Class 傢俱收納|曬衣架
# Precision: 0.0
# Recall: None
#
#
# Class 傢俱收納|桌/茶几/化妝台
# Precision: None
# Recall: None
#
#
# Class 傢俱收納|椅子/矮凳
# Precision: 0.0
# Recall: None
#
#
# Class 傢俱收納|櫥櫃/櫃子
# Precision: None
# Recall: None
#
#
# Class 傢俱收納|沙發
# Precision: None
# Recall: None
#
#
# Class 傢俱收納|電腦椅
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|保潔墊/保暖墊
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|地墊/地毯/拖鞋
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|壁飾/時鐘/掛畫
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|專櫃品牌寢具
# Precision: 0.0
# Recall: None
#
#
# Class 傢飾寢具|床包/床罩
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|床墊
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|日式床墊/折疊床墊
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|枕頭/枕套/枕巾
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|毛巾/浴巾
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|沙發墊/坐墊/抱枕
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|涼蓆/麻將蓆/冰涼墊
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|窗簾/門簾
# Precision: None
# Recall: None
#
#
# Class 傢飾寢具|被子/毯子/被套
# Precision: 0.0
# Recall: None
#
#
# Class 傢飾寢具|記憶床墊/乳膠床墊
# Precision: None
# Recall: None
#
#
# Class 內衣|塑身衣褲
# Precision: None
# Recall: None
#
#
# Class 內衣|女內著
# Precision: None
# Recall: 0.0
#
#
# Class 內衣|專櫃內衣
# Precision: None
# Recall: None
#
#
# Class 內衣|泳裝/比基尼
# Precision: None
# Recall: None
#
#
# Class 內衣|男內著
# Precision: None
# Recall: None
#
#
# Class 內衣|男內衣褲
# Precision: 0.0
# Recall: 0.0
#
#
# Class 內衣|睡衣/居家服
# Precision: None
# Recall: None
#
#
# Class 內衣|網路流行內衣
# Precision: None
# Recall: None
#
#
# Class 內衣|襪子
# Precision: 0.0
# Recall: None
#
#
# Class 加值/軟體|myBook電子書
# Precision: None
# Recall: None
#
#
# Class 加值/軟體|微軟軟體
# Precision: None
# Recall: None
#
#
# Class 加值/軟體|數位加值/遊戲
# Precision: None
# Recall: 0.0
#
#
# Class 加值/軟體|有聲書
# Precision: None
# Recall: None
#
#
# Class 加值/軟體|電腦/防毒軟體
# Precision: None
# Recall: None
#
#
# Class 圖書影音|人文史地
# Precision: None
# Recall: None
#
#
# Class 圖書影音|商業理財
# Precision: None
# Recall: None
#
#
# Class 圖書影音|宗教命理
# Precision: None
# Recall: None
#
#
# Class 圖書影音|影音
# Precision: None
# Recall: None
#
#
# Class 圖書影音|心理勵志
# Precision: None
# Recall: None
#
#
# Class 圖書影音|政府出版/教科書
# Precision: None
# Recall: None
#
#
# Class 圖書影音|文學小說
# Precision: None
# Recall: None
#
#
# Class 圖書影音|旅遊
# Precision: None
# Recall: None
#
#
# Class 圖書影音|書店排行榜
# Precision: None
# Recall: 0.0
#
#
# Class 圖書影音|漫畫
# Precision: None
# Recall: None
#
#
# Class 圖書影音|生活風格
# Precision: None
# Recall: None
#
#
# Class 圖書影音|社會科學
# Precision: None
# Recall: None
#
#
# Class 圖書影音|童書/教具
# Precision: None
# Recall: None
#
#
# Class 圖書影音|考試用書
# Precision: None
# Recall: None
#
#
# Class 圖書影音|自然科普
# Precision: None
# Recall: None
#
#
# Class 圖書影音|藝術設計
# Precision: 0.0
# Recall: None
#
#
# Class 圖書影音|親子教養
# Precision: None
# Recall: None
#
#
# Class 圖書影音|語言學習
# Precision: None
# Recall: None
#
#
# Class 圖書影音|輕小說
# Precision: None
# Recall: None
#
#
# Class 圖書影音|醫療保健
# Precision: None
# Recall: None
#
#
# Class 圖書影音|雜誌訂閱
# Precision: None
# Recall: None
#
#
# Class 圖書影音|電腦資訊
# Precision: None
# Recall: None
#
#
# Class 圖書影音|飲食
# Precision: 0.0
# Recall: None
#
#
# Class 宗教/藝術|宗教用品
# Precision: None
# Recall: None
#
#
# Class 宗教/藝術|藝術/蒐藏品
# Precision: None
# Recall: None
#
#
# Class 宗教/藝術|開運風水
# Precision: 0.0
# Recall: None
#
#
# Class 宗教/藝術|香品/祈福
# Precision: 0.0
# Recall: 0.0
#
#
# Class 家電|3M家電
# Precision: None
# Recall: None
#
#
# Class 家電|LG吸塵器
# Precision: None
# Recall: None
#
#
# Class 家電|PlayStation
# Precision: None
# Recall: None
#
#
# Class 家電|乾衣機/電子衣櫥
# Precision: None
# Recall: None
#
#
# Class 家電|免治馬桶
# Precision: None
# Recall: None
#
#
# Class 家電|冰櫃/冷凍櫃
# Precision: None
# Recall: None
#
#
# Class 家電|冰箱
# Precision: None
# Recall: None
#
#
# Class 家電|冷/熱食物調理
# Precision: None
# Recall: None
#
#
# Class 家電|冷氣/暖氣
# Precision: None
# Recall: None
#
#
# Class 家電|刮鬍刀
# Precision: None
# Recall: None
#
#
# Class 家電|吸塵器
# Precision: None
# Recall: None
#
#
# Class 家電|吹風機/造型美髮
# Precision: None
# Recall: None
#
#
# Class 家電|咖啡機
# Precision: None
# Recall: None
#
#
# Class 家電|廚衛三機館
# Precision: 0.0
# Recall: None
#
#
# Class 家電|快煮壺/熱水瓶
# Precision: None
# Recall: None
#
#
# Class 家電|投影機
# Precision: None
# Recall: None
#
#
# Class 家電|捕蚊家電
# Precision: None
# Recall: None
#
#
# Class 家電|掃地機
# Precision: None
# Recall: None
#
#
# Class 家電|排油煙機
# Precision: None
# Recall: None
#
#
# Class 家電|料理電器
# Precision: None
# Recall: None
#
#
# Class 家電|洗衣機
# Precision: None
# Recall: None
#
#
# Class 家電|液晶電視
# Precision: None
# Recall: None
#
#
# Class 家電|淨水設備
# Precision: None
# Recall: None
#
#
# Class 家電|清淨機
# Precision: None
# Recall: None
#
#
# Class 家電|清潔/消毒
# Precision: None
# Recall: None
#
#
# Class 家電|滾筒洗衣機
# Precision: None
# Recall: None
#
#
# Class 家電|潔牙/電動牙刷
# Precision: None
# Recall: None
#
#
# Class 家電|烘焙家電
# Precision: None
# Recall: None
#
#
# Class 家電|烘碗/洗碗
# Precision: None
# Recall: None
#
#
# Class 家電|烤箱/微波爐
# Precision: None
# Recall: None
#
#
# Class 家電|照明/整燙裁縫
# Precision: None
# Recall: None
#
#
# Class 家電|熱水器
# Precision: None
# Recall: None
#
#
# Class 家電|瓦斯爐
# Precision: None
# Recall: None
#
#
# Class 家電|福利品
# Precision: None
# Recall: None
#
#
# Class 家電|移動式空調
# Precision: None
# Recall: None
#
#
# Class 家電|美容電器
# Precision: None
# Recall: 0.0
#
#
# Class 家電|蒸氣洗衣機
# Precision: None
# Recall: None
#
#
# Class 家電|視聽娛樂
# Precision: None
# Recall: None
#
#
# Class 家電|通訊/辦公
# Precision: None
# Recall: None
#
#
# Class 家電|酒櫃
# Precision: None
# Recall: None
#
#
# Class 家電|除濕機
# Precision: None
# Recall: None
#
#
# Class 家電|電暖器
# Precision: None
# Recall: None
#
#
# Class 家電|電玩遊戲
# Precision: 0.0
# Recall: None
#
#
# Class 家電|電鍋/電子鍋
# Precision: None
# Recall: None
#
#
# Class 家電|音響/家庭劇院
# Precision: 0.0
# Recall: None
#
#
# Class 家電|風扇
# Precision: None
# Recall: None
#
#
# Class 家電|飲水設備
# Precision: None
# Recall: None
#
#
# Class 寵物|寵物玩具/居家用品
# Precision: 0.0
# Recall: None
#
#
# Class 寵物|寵物美容/外出用品
# Precision: 0.0
# Recall: None
#
#
# Class 寵物|寵物零食/保健
# Precision: None
# Recall: None
#
#
# Class 寵物|水族/小動物
# Precision: 0.0
# Recall: None
#
#
# Class 寵物|狗罐頭/鮮食
# Precision: None
# Recall: None
#
#
# Class 寵物|狗飼料/乾糧
# Precision: None
# Recall: None
#
#
# Class 寵物|貓砂/便盆/尿布墊
# Precision: 0.0
# Recall: None
#
#
# Class 寵物|貓罐頭/鮮食
# Precision: None
# Recall: None
#
#
# Class 寵物|貓飼料/乾糧
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|MIT保養品牌
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|唇頰彩
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|國營保養品牌
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|專櫃保養品牌
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|專櫃彩妝品牌
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|底妝
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|彩妝刷具
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|指甲油/光療
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|擴香/蠟燭
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|水氧機/精油
# Precision: 0.0
# Recall: None
#
#
# Class 彩妝保養|男士保養品牌
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|看看買-美妝保養
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|眼眉彩
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|私密保養
# Precision: None
# Recall: None
#
#
# Class 彩妝保養|精油
# Precision: 0.0
# Recall: None
#
#
# Class 彩妝保養|美容工具小物
# Precision: 0.0
# Recall: None
#
#
# Class 彩妝保養|身體保養
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|醫美保養品牌
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|開架保養品牌
# Precision: 0.0
# Recall: 0.0
#
#
# Class 彩妝保養|開架彩妝品牌
# Precision: None
# Recall: 0.0
#
#
# Class 彩妝保養|香氛保養品牌
# Precision: 0.0
# Recall: 0.0
#
#
# Class 彩妝保養|香水
# Precision: None
# Recall: 0.0
#
#
# Class 戶外用品|戶外/露營
# Precision: 0.0
# Recall: None
#
#
# Class 戶外用品|烤肉/野餐
# Precision: None
# Recall: None
#
#
# Class 戶外用品|登山健行
# Precision: 0.0
# Recall: None
#
#
# Class 戶外用品|軍迷用品
# Precision: 0.0
# Recall: None
#
#
# Class 戶外用品|釣具
# Precision: None
# Recall: None
#
#
# Class 戶外用品|雨傘/雨衣
# Precision: None
# Recall: None
#
#
# Class 手機/平板|3C福利品
# Precision: None
# Recall: None
#
#
# Class 手機/平板|Apple原廠週邊
# Precision: None
# Recall: None
#
#
# Class 手機/平板|Apple週邊
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|MP5/MP3
# Precision: None
# Recall: None
#
#
# Class 手機/平板|Mac/iPad
# Precision: None
# Recall: None
#
#
# Class 手機/平板|Motorola
# Precision: None
# Recall: None
#
#
# Class 手機/平板|NOKIA
# Precision: None
# Recall: None
#
#
# Class 手機/平板|OPPO
# Precision: None
# Recall: None
#
#
# Class 手機/平板|SONY
# Precision: None
# Recall: None
#
#
# Class 手機/平板|SONY相機
# Precision: None
# Recall: None
#
#
# Class 手機/平板|USB週邊
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|iPad
# Precision: None
# Recall: None
#
#
# Class 手機/平板|iPad/Mac保護週邊
# Precision: None
# Recall: None
#
#
# Class 手機/平板|iPhone
# Precision: None
# Recall: None
#
#
# Class 手機/平板|vivo
# Precision: None
# Recall: None
#
#
# Class 手機/平板|一般手機
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|喇叭/藍牙喇叭
# Precision: None
# Recall: None
#
#
# Class 手機/平板|安卓保護貼
# Precision: None
# Recall: None
#
#
# Class 手機/平板|安卓原廠配件
# Precision: None
# Recall: None
#
#
# Class 手機/平板|安卓殼/套
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|小米
# Precision: None
# Recall: None
#
#
# Class 手機/平板|平板電腦
# Precision: None
# Recall: None
#
#
# Class 手機/平板|手機/平板充電週邊
# Precision: None
# Recall: None
#
#
# Class 手機/平板|手機/平板週邊
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|旅遊上網卡
# Precision: None
# Recall: None
#
#
# Class 手機/平板|智慧型手機
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|穿戴裝置
# Precision: None
# Recall: None
#
#
# Class 手機/平板|行動電源/無線充電
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|行動電源/電池
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|語言學習/翻譯機
# Precision: None
# Recall: None
#
#
# Class 手機/平板|通訊耳機
# Precision: 0.0
# Recall: None
#
#
# Class 手機/平板|電池/充電電池
# Precision: None
# Recall: None
#
#
# Class 手機/平板|音樂耳機
# Precision: 0.0
# Recall: None
#
#
# Class 文具樂器|文具用品
# Precision: None
# Recall: None
#
#
# Class 文具樂器|樂器
# Precision: None
# Recall: None
#
#
# Class 文具樂器|辦公用品
# Precision: 0.0
# Recall: None
#
#
# Class 旅遊/住宿|國內旅遊
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|momo超市
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|曬衣架/洗衣袋
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|洗衣精/粉
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|清潔劑
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|清潔工具
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|濕紙巾
# Precision: None
# Recall: None
#
#
# Class 日用/紙品|衛生紙
# Precision: None
# Recall: 0.0
#
#
# Class 日用/紙品|除蟲除濕
# Precision: None
# Recall: None
#
#
# Class 服飾|休閒牛仔服飾
# Precision: None
# Recall: 0.0
#
#
# Class 服飾|女裝
# Precision: 0.0
# Recall: None
#
#
# Class 服飾|快時尚嚴選店
# Precision: 0.0
# Recall: 0.0
#
#
# Class 服飾|推薦品牌
# Precision: None
# Recall: 0.0
#
#
# Class 服飾|正式西裝
# Precision: None
# Recall: None
#
#
# Class 服飾|泳裝/比基尼
# Precision: None
# Recall: 0.0
#
#
# Class 服飾|男裝
# Precision: 0.0
# Recall: 0.0
#
#
# Class 服飾|運動機能服飾
# Precision: 0.0
# Recall: None
#
#
# Class 服飾|飾品配件
# Precision: 0.0
# Recall: 0.0
#
#
# Class 母嬰玩具|兒童寢具/睡袋
# Precision: 0.0
# Recall: None
#
#
# Class 母嬰玩具|兒童成長傢俱
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|品牌玩具
# Precision: 0.0
# Recall: None
#
#
# Class 母嬰玩具|奶瓶/消毒鍋/吸乳器
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|奶粉/副食品
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|嬰兒床/遊戲床
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|嬰幼兒寢具/哺乳枕
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|嬰幼兒洗沐保養
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|嬰幼兒浴盆/便器
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|嬰童紙尿褲
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|成人紙尿褲
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|手推車/安全汽座
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|揹巾腰凳/媽媽包
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|書包/童包
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|桌遊
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|模型/公仔/動漫
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|爬行地墊/安全圍欄
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|玩具
# Precision: 0.0
# Recall: None
#
#
# Class 母嬰玩具|積木
# Precision: 0.0
# Recall: None
#
#
# Class 母嬰玩具|童裝
# Precision: 0.0
# Recall: None
#
#
# Class 母嬰玩具|童鞋/童襪
# Precision: None
# Recall: None
#
#
# Class 母嬰玩具|餐具/餐椅/調理機
# Precision: 0.0
# Recall: None
#
#
# Class 生鮮|冷凍快配
# Precision: None
# Recall: 0.0
#
#
# Class 生鮮|冷凍食品
# Precision: 0.0
# Recall: 0.0
#
#
# Class 生鮮|年菜/年貨大街
# Precision: None
# Recall: 0.0
#
#
# Class 生鮮|水產海鮮
# Precision: None
# Recall: None
#
#
# Class 生鮮|滴雞精
# Precision: None
# Recall: None
#
#
# Class 生鮮|生鮮肉品
# Precision: None
# Recall: 0.0
#
#
# Class 生鮮|蔬菜水果
# Precision: 0.0
# Recall: 0.0
#
#
# Class 直配大陸|直配大陸
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|單眼相機
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|單眼鏡頭
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|專業攝影配件
# Precision: 0.0
# Recall: None
#
#
# Class 相機/攝影|微單眼
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|攝影包/腳架/穩定器
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|數位相機
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|相機電池
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|空拍/運動攝影機
# Precision: 0.0
# Recall: None
#
#
# Class 相機/攝影|記憶卡
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|鏡頭濾鏡
# Precision: None
# Recall: None
#
#
# Class 相機/攝影|防潮箱
# Precision: None
# Recall: None
#
#
# Class 看看買|BEBEPOSHE
# Precision: None
# Recall: None
#
#
# Class 看看買|快閃活動
# Precision: 0.0
# Recall: 0.0
#
#
# Class 看看買|看看買-3C家電
# Precision: None
# Recall: None
#
#
# Class 看看買|看看買-內塑衣
# Precision: None
# Recall: None
#
#
# Class 看看買|看看買-服飾
# Precision: None
# Recall: None
#
#
# Class 看看買|看看買-海外獨家
# Precision: None
# Recall: None
#
#
# Class 看看買|看看買-生活用品
# Precision: None
# Recall: None
#
#
# Class 看看買|看看買-精品鞋包
# Precision: None
# Recall: None
#
#
# Class 看看買|看看買-食品
# Precision: None
# Recall: None
#
#
# Class 票券|玩樂/生活券
# Precision: None
# Recall: None
#
#
# Class 票券|美容舒壓券
# Precision: None
# Recall: None
#
#
# Class 票券|美食餐券
# Precision: None
# Recall: 0.0
#
#
# Class 票券|飯店/住宿券
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|國際精品包
# Precision: 0.0
# Recall: None
#
#
# Class 精品/飾品|國際精品夾
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|太陽眼鏡/眼鏡
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|專櫃黃金珠寶
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|手錶
# Precision: 0.0
# Recall: None
#
#
# Class 精品/飾品|歐系精品
# Precision: 0.0
# Recall: None
#
#
# Class 精品/飾品|珠寶/玉石
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|男仕精品
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|精品配飾
# Precision: 0.0
# Recall: None
#
#
# Class 精品/飾品|精品錶/瑞士錶
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|網路品牌黃金珠寶
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|鐘錶周邊
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|鑽石
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|飾品/穿搭配飾
# Precision: None
# Recall: None
#
#
# Class 精品/飾品|黃金/金飾
# Precision: None
# Recall: None
#
#
# Class 綠色生活|綠色生活館│有機認證•環保減塑
# Precision: None
# Recall: None
#
#
# Class 車|GPS/行車紀錄
# Precision: None
# Recall: None
#
#
# Class 車|機車/用品
# Precision: None
# Recall: None
#
#
# Class 車|汽車百貨
# Precision: 0.0
# Recall: None
#
#
# Class 車|自行車
# Precision: 0.0
# Recall: None
#
#
# Class 車|電動車/滑板
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|健身器材
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|按摩器材
# Precision: 0.0
# Recall: None
#
#
# Class 運動/按摩|按摩椅
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|水上運動
# Precision: 0.0
# Recall: None
#
#
# Class 運動/按摩|泡腳機/桑拿屋
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|球類運動
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|瑜珈/體適能
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|運動護具
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|重量訓練器材
# Precision: None
# Recall: None
#
#
# Class 運動/按摩|陸上運動
# Precision: 0.0
# Recall: None
#
#
# Class 電腦/週邊|CPU中央處理器
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|DIY組裝電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|LCD電腦螢幕
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|MacBook/iMac
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|NAS網路硬碟
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|SSD固態硬碟
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|UPS不斷電系統
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|主機板/擴充卡
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|企業專區
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|內接式硬碟
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|品牌桌上型電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|商用桌上型電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|商用筆記型電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|噴墨印表機
# Precision: None
# Recall: None
# Class 電腦/週邊|墨水/碳粉匣
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|外接式硬碟
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|插座/延長線
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|智能居家/視訊監控
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|智能居家/電子鎖
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|標籤機/相印機/其他列印
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|機殼/電源/裝機配件
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|滑鼠/鍵盤
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|筆記型電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|筆電包/配件
# Precision: 0.0
# Recall: None
#
#
# Class 電腦/週邊|網路設備/分享器
# Precision: 0.0
# Recall: None
#
#
# Class 電腦/週邊|繪圖/手寫板
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|記憶體
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|辦公事務/營業設備
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|隨身碟
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|雷射印表機
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|電競LCD電腦螢幕
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|電競桌機/組裝電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|電競筆記型電腦
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|電競週邊
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|電腦週邊/線材
# Precision: None
# Recall: None
#
#
# Class 電腦/週邊|顯示卡
# Precision: None
# Recall: None
#
#
# Class 鞋包箱|NIKE
# Precision: None
# Recall: None
#
#
# Class 鞋包箱|品牌休閒鞋
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|專櫃包
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|專櫃品牌行李箱
# Precision: None
# Recall: None
#
#
# Class 鞋包箱|專櫃鞋
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|流行包
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|流行鞋款
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|行李箱
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|運動鞋
# Precision: 0.0
# Recall: None
#
#
# Class 鞋包箱|鞋材用品
# Precision: None
# Recall: None
#
#
# Class 食品飲料|休閒零食
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|咖啡
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|年菜/年貨大街
# Precision: 0.0
# Recall: 0.0
#
#
# Class 食品飲料|有機食品
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|沖調/奶粉
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|油/調味
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|礦泉水
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|米/麵/泡麵
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|罐頭/食材/烘焙
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|美食出清品
# Precision: None
# Recall: None
#
#
# Class 食品飲料|美食韓國展
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|茶葉/茶包
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|蛋糕甜點
# Precision: 0.0
# Recall: 0.0
#
#
# Class 食品飲料|蜂蜜/蜂製品/醋
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|進口零食
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|飲料
# Precision: None
# Recall: 0.0
#
#
# Class 食品飲料|麥片/穀類
# Precision: None
# Recall: 0.0
#
#
# Class 餐廚用品|保鮮盒/便當盒
# Precision: 0.0
# Recall: 0.0
#
#
# Class 餐廚用品|刀具砧板
# Precision: 0.0
# Recall: None
#
#
# Class 餐廚用品|咖啡用品
# Precision: None
# Recall: None
#
#
# Class 餐廚用品|廚房料理配件
# Precision: None
# Recall: None
#
#
# Class 餐廚用品|杯子/馬克杯
# Precision: 0.0
# Recall: None
#
#
# Class 餐廚用品|濾水壺/桌上壺
# Precision: None
# Recall: None
#
#
# Class 餐廚用品|碗盤餐具
# Precision: None
# Recall: 0.0
#
#
# Class 餐廚用品|茶具/茶壺
# Precision: 0.0
# Recall: None
#
#
# Class 餐廚用品|酒器酒杯
# Precision: None
# Recall: None
#
#
# Class 餐廚用品|鍋具
# Precision: 0.0
# Recall: None
#
#
# Class 餐廚用品|隨行杯/保溫瓶
# Precision: 0.0
# Recall: None
#
#
# Class 餐廚用品|隨行杯/保溫瓶(專案)
# Precision: None
# Recall: None

# %%
# 印出部分模型預測與實際label
from sklearn.metrics import accuracy_score, precision_score, recall_score, f1_score, roc_curve, auc, confusion_matrix
y_pred = model.predict(X_test)
print("X: ", testing_set['Preprocessed Item Name'][:10])
print("Y hat: ", y_pred[:10])
print("Y: ", y_test[:10])
print(accuracy_score(y_test, y_pred))

print("---------------------------------")
print("\n印y hat各類數量: ")
(unique, counts) = np.unique(y_pred, return_counts=True)
frequencies = np.asarray((unique, counts)).T
print(frequencies)
print("共", len(frequencies), "類")

print("\n印Y各類數量: ")
(unique, counts) = np.unique(y_test, return_counts=True)
frequencies = np.asarray((unique, counts)).T
print(frequencies)
print("共", len(frequencies), "類")
# Out:
# X:  0          小熊餅乾草莓蛋糕風味g
# 1            西村嬰兒野菜蛋酥g
# 2    熊野油脂PharmaACT超酷涼沐
# 3         時尚大師色眼影盤冷淡沙漠
# 4              保濕全能修護組
# 5         SIMONCOLL黑巧克
# 6            奢華訂製鏡光水唇釉
# 7                   僑俐
# 8      PAPILLON法國洛克福乾酪
# 9              香奈兒之水系列
# Name: Preprocessed Item Name, dtype: object
# Y hat:  ['食品飲料' '傢飾寢具' '電腦/週邊' '彩妝保養' '精品/飾品' '加值/軟體' '加值/軟體' '寵物' '戶外用品' '旅遊/住宿']
# Y:  0    食品飲料
# 1    食品飲料
# 2    個人清潔
# 3    彩妝保養
# 4    彩妝保養
# 5    食品飲料
# 6    彩妝保養
# 7    餐廚用品
# 8    食品飲料
# 9    彩妝保養
# Name: category1, dtype: object
# 0.015706806282722512
# ---------------------------------
#
# 印y hat各類數量:
# [['outlet名品匯' 4]
#  ['保健/醫療' 1]
#  ['修繕園藝' 3]
#  ['個人清潔' 6]
#  ['傢飾寢具' 10]
#  ['加值/軟體' 15]
#  ['圖書影音' 1]
#  ['家電' 7]
#  ['寵物' 18]
#  ['彩妝保養' 3]
#  ['戶外用品' 7]
#  ['手機/平板' 13]
#  ['文具樂器' 4]
#  ['旅遊/住宿' 23]
#  ['日用/紙品' 2]
#  ['服飾' 6]
#  ['母嬰玩具' 6]
#  ['直配大陸' 3]
#  ['相機/攝影' 10]
#  ['票券' 2]
#  ['精品/飾品' 7]
#  ['綠色生活' 1]
#  ['車' 12]
#  ['運動/按摩' 1]
#  ['電腦/週邊' 13]
#  ['鞋包箱' 9]
#  ['食品飲料' 1]
#  ['餐廚用品' 3]]
# 共 28 類
#
# 印Y各類數量:
# [['outlet名品匯' 1]
#  ['保健/醫療' 3]
#  ['個人清潔' 7]
#  ['傢俱收納' 2]
#  ['內衣' 4]
#  ['加值/軟體' 1]
#  ['圖書影音' 1]
#  ['宗教/藝術' 1]
#  ['家電' 1]
#  ['彩妝保養' 28]
#  ['日用/紙品' 1]
#  ['服飾' 7]
#  ['生鮮' 21]
#  ['看看買' 1]
#  ['票券' 2]
#  ['食品飲料' 107]
#  ['餐廚用品' 3]]
# 共 17 類
